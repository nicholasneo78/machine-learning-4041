# %%
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import get_file
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import cv2
import os
import glob
import pandas as pd
import h5py
import cvlib as cv

# %%
class SmallerVGGNet:
    @staticmethod
    def build(width, height, depth, classes):
        model = Sequential()
        inputShape = (height, width, depth)
        chanDim = -1

        if K.image_data_format() == "channels_first":
            inputShape = (depth, height, width)
            chanDim = 1

        model.add(Conv2D(32, (3,3), padding="same", input_shape=inputShape))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(3,3)))
        model.add(Dropout(0.25))

        model.add(Conv2D(64, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(64, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Dropout(0.25))

        model.add(Conv2D(128, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(Conv2D(128, (3,3), padding="same"))
        model.add(Activation("relu"))
        model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Dropout(0.25))

        model.add(Flatten())
        model.add(Dense(1024))
        model.add(Activation("relu"))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        model.add(Dense(classes))
        model.add(Activation("softmax"))

        return model

# %%
def generate_h5_data(data,labels,filename):
    assert(type(filename) is str)
    assert(len(data) == len(labels)) 
    try:
        filepath= f'./{filename}.h5'


        h5data = h5py.File(filepath, 'w')
        h5data.create_dataset('image',data= data)
        h5data['label'] = labels


    finally:
        h5data.close()

#NO NEED FOR THIS EXERCISE
def load_h5_data(h5filepath):
    h5file = h5py.File(h5filepath, "r")
    try:
        x_fieldname,y_fieldname, = h5file.keys()   #this order is Gfriend files
        print("The keys are: ", h5file.keys())
        data = np.array(h5file['image'][:]) # your test set features
        labels = np.array(h5file['label'][:]) # your test set labels
        print("The shape of x_field",data.shape)
        print("The shape of y_field",labels.shape)
    finally:
        h5file.close()
    return data, labels

# %%
def show_20_images(img_array,label_array,offset=0):
    
    assert(len(img_array)==len(label_array))
    
    datalen = len(img_array)
    numOfIter = min(datalen,20)
    
    if numOfIter < 20:
        offset = 0  #if numOfIter < 20, it means it equals datalen, which is less than 20 fed in. So no need offset
        
    numOfRow = numOfIter//4 + (numOfIter%4 != 0)   #a ceiling function
    
    plt.rcParams['figure.figsize'] = (60.0, 100.0) 
    print(img_array.shape)
    num_px = img_array.shape[1] #shape is (m, num_px,num_px,3)
    for i in range(numOfIter):
        plt.subplot(5,4,i+1)  #plot 5 by 4 grid
        #plt.imshow(img_array[i+offset])
        img_preview = img_array[i+offset].reshape(num_px,num_px,3)
        img_preview = np.float32(img_preview)
        img_preview = cv2.cvtColor(img_preview, cv2.COLOR_BGR2RGB)
        plt.imshow(img_preview, interpolation='nearest')  #take only the num_px
        plt.axis('off')
        #print(f'IMG {i+1} is labelled {label_array[i+offset]}')
#         _class = df_unique['breed'][int(label_array[i+offset])]
#         plt.title("Class: " + _class,fontsize = 50)

# %%
epochs = 100
lr = 1e-3
batch_size = 64
img_dims = (96,96,3)

# %%
df = pd.read_csv("Datasets/labels.csv")
print(df)
df_unique = df.drop_duplicates(subset=['breed'])
df_unique= df_unique.reset_index(drop=True)
print(df_unique)
# Out:
#                                      id                     breed
# 0      000bec180eb18c7604dcecc8fe0dba07               boston_bull
# 1      001513dfcb2ffafc82cccf4d8bbaba97                     dingo
# 2      001cdf01b096e06d78e9e5112d419397                  pekinese
# 3      00214f311d5d2247d5dfe4fe24b2303d                  bluetick
# 4      0021f9ceb3235effd7fcde7f7538ed62          golden_retriever
# ...                                 ...                       ...
# 10217  ffd25009d635cfd16e793503ac5edef0                    borzoi
# 10218  ffd3f636f7f379c51ba3648a9ff8254f            dandie_dinmont
# 10219  ffe2ca6c940cddfee68fa3cc6c63213f                  airedale
# 10220  ffe5f6d8e2bff356e9482a80a6e29aac        miniature_pinscher
# 10221  fff43b07992508bc822f33d8ffd902ae  chesapeake_bay_retriever
#
# [10222 rows x 2 columns]
#                                    id                 breed
# 0    000bec180eb18c7604dcecc8fe0dba07           boston_bull
# 1    001513dfcb2ffafc82cccf4d8bbaba97                 dingo
# 2    001cdf01b096e06d78e9e5112d419397              pekinese
# 3    00214f311d5d2247d5dfe4fe24b2303d              bluetick
# 4    0021f9ceb3235effd7fcde7f7538ed62      golden_retriever
# ..                                ...                   ...
# 115  0a86c8b48bddb0155645f3a27f48292f  bouvier_des_flandres
# 116  0a8b6985bbe58a58909b5ef0a7d5a1aa       tibetan_mastiff
# 117  0b2d69f59303805f17055bd59615a297      english_springer
# 118  0b6c5bc46b7a0e29cddfa45b0b786d09        cocker_spaniel
# 119  118089e60763cbdba239cac747a54a6e            rottweiler
#
# [120 rows x 2 columns]

# %%
BreedDict = {}

# %%
for ind in df_unique.index: 
     print(df_unique['breed'][ind])
     BreedDict[df_unique['breed'][ind]]=ind
# Out:
# boston_bull
# dingo
# pekinese
# bluetick
# golden_retriever
# bedlington_terrier
# borzoi
# basenji
# scottish_deerhound
# shetland_sheepdog
# walker_hound
# maltese_dog
# norfolk_terrier
# african_hunting_dog
# wire-haired_fox_terrier
# redbone
# lakeland_terrier
# boxer
# doberman
# otterhound
# standard_schnauzer
# irish_water_spaniel
# black-and-tan_coonhound
# cairn
# affenpinscher
# labrador_retriever
# ibizan_hound
# english_setter
# weimaraner
# giant_schnauzer
# groenendael
# dhole
# toy_poodle
# border_terrier
# tibetan_terrier
# norwegian_elkhound
# shih-tzu
# irish_terrier
# kuvasz
# german_shepherd
# greater_swiss_mountain_dog
# basset
# australian_terrier
# schipperke
# rhodesian_ridgeback
# irish_setter
# appenzeller
# bloodhound
# samoyed
# miniature_schnauzer
# brittany_spaniel
# kelpie
# papillon
# border_collie
# entlebucher
# collie
# malamute
# welsh_springer_spaniel
# chihuahua
# saluki
# pug
# malinois
# komondor
# airedale
# leonberg
# mexican_hairless
# bull_mastiff
# bernese_mountain_dog
# american_staffordshire_terrier
# lhasa
# cardigan
# italian_greyhound
# clumber
# scotch_terrier
# afghan_hound
# old_english_sheepdog
# saint_bernard
# miniature_pinscher
# eskimo_dog
# irish_wolfhound
# brabancon_griffon
# toy_terrier
# chow
# flat-coated_retriever
# norwich_terrier
# soft-coated_wheaten_terrier
# staffordshire_bullterrier
# english_foxhound
# gordon_setter
# siberian_husky
# newfoundland
# briard
# chesapeake_bay_retriever
# dandie_dinmont
# great_pyrenees
# beagle
# vizsla
# west_highland_white_terrier
# kerry_blue_terrier
# whippet
# sealyham_terrier
# standard_poodle
# keeshond
# japanese_spaniel
# miniature_poodle
# pomeranian
# curly-coated_retriever
# yorkshire_terrier
# pembroke
# great_dane
# blenheim_spaniel
# silky_terrier
# sussex_spaniel
# german_short-haired_pointer
# french_bulldog
# bouvier_des_flandres
# tibetan_mastiff
# english_springer
# cocker_spaniel
# rottweiler

# %%
BreedDict['rottweiler']
# Out:
# 119

# %%
data = []
labels = []

# %% [markdown]
# # Train

# %%
image_files_train = [f for f in glob.glob("Datasets/train" + "/**/*", recursive=True) if not os.path.isdir(f)]
random.seed(42)
random.shuffle(image_files_train)
s=os.path.basename(image_files_train[0])
parts = s.split(".")
print(parts[0])
dftrain_lock=df.loc[df['id'] == parts[0]]
print(dftrain_lock['breed'].to_string(index=False).lstrip())
dftrain_lock['breed'].to_string(index=False).lstrip()=="soft-coated_wheaten_terrier"
# Out:
# f6209cf3313e3368c376dbfa13f335cc
# soft-coated_wheaten_terrier
# True

# %%
# create groud-truth label from the image path
for img in image_files_train:
    s=os.path.basename(img)
    parts = s.split(".")
    name=parts[0]
    dftrain_lock=df.loc[df['id'] == parts[0]]
    if dftrain_lock.empty:
        continue
    else:
        image = cv2.imread(img)
        image = cv2.resize(image, (img_dims[0],img_dims[1]))
        image = img_to_array(image)
        data.append(image)
        label = BreedDict[dftrain_lock['breed'].to_string(index=False).lstrip()]
        labels.append([label])

# %%
# pre-processing
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
print('x_data shape:', data.shape)
print('y_data shape:', labels.shape)
# Out:
# x_data shape: (10222, 96, 96, 3)
# y_data shape: (10222, 1)

# %%
x=labels[20]
print(int(x))
# Out:
# 93

# %%
show_20_images(data,labels,20)
# Out:
# (10222, 96, 96, 3)

# %%
with open('trainout.txt', 'w') as f:
    for item in labels:
        f.write("%s\n" % item)

# %%
# split dataset for training and validation
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.2,
                                                  random_state=42)
trainY = to_categorical(trainY, num_classes=120)
testY = to_categorical(testY, num_classes=120)

# %%
# augmenting datset 
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                         height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                         horizontal_flip=True, fill_mode="nearest")

# build model
model = SmallerVGGNet.build(width=img_dims[0], height=img_dims[1], depth=img_dims[2],
                            classes=120)
# compile the model, need to reduce lr to reduce overfit
opt = Adam(lr=lr, decay=lr/epochs)
model.compile(loss="CategoricalCrossentropy", optimizer=opt, metrics=["accuracy"])

# train the model
H = model.fit_generator(aug.flow(trainX, trainY, batch_size=batch_size),
                        validation_data=(testX,testY),
                        steps_per_epoch=len(trainX) // batch_size,
                        epochs=epochs, verbose=1)

# save the model to disk
model.save("my_model2")

# plot training/validation loss/accuracy
plt.style.use("ggplot")
plt.figure(figsize=(8, 6))
N = epochs
plt.plot(np.arange(0,N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0,N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0,N), H.history["val_accuracy"], label="val_acc")

plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right")
plt.show()
# save plot to disk
plt.savefig("my_figures2")
# Out:
# Epoch 1/100
# 127/127 [==============================] - 17s 134ms/step - loss: 5.4644 - accuracy: 0.0232 - val_loss: 6.9323 - val_accuracy: 0.0064
# Epoch 2/100
# 127/127 [==============================] - 17s 133ms/step - loss: 5.0651 - accuracy: 0.0330 - val_loss: 6.6466 - val_accuracy: 0.0147
# Epoch 3/100
# 127/127 [==============================] - 17s 135ms/step - loss: 4.8155 - accuracy: 0.0463 - val_loss: 6.3693 - val_accuracy: 0.0215
# Epoch 43/100
# 127/127 [==============================] - 16s 130ms/step - loss: 1.6685 - accuracy: 0.5451 - val_loss: 4.7544 - val_accuracy: 0.1555
# Epoch 44/100
# 127/127 [==============================] - 17s 130ms/step - loss: 1.6390 - accuracy: 0.5484 - val_loss: 4.6542 - val_accuracy: 0.1643
# Epoch 45/100
# 127/127 [==============================] - 17s 130ms/step - loss: 1.6300 - accuracy: 0.5414 - val_loss: 4.7876 - val_accuracy: 0.1359
# Epoch 46/100
# 127/127 [==============================] - 17s 130ms/step - loss: 1.5467 - accuracy: 0.5723 - val_loss: 4.2544 - val_accuracy: 0.1888
# Epoch 47/100
# 127/127 [==============================] - 17s 131ms/step - loss: 1.5948 - accuracy: 0.5557 - val_loss: 4.6649 - val_accuracy: 0.1545
# Epoch 48/100
# 127/127 [==============================] - 17s 130ms/step - loss: 1.5326 - accuracy: 0.5743 - val_loss: 4.5949 - val_accuracy: 0.1760
# Epoch 49/100
# 127/127 [==============================] - 17s 137ms/step - loss: 1.4970 - accuracy: 0.5801 - val_loss: 4.8371 - val_accuracy: 0.1526
# Epoch 50/100
# 127/127 [==============================] - 19s 149ms/step - loss: 1.4533 - accuracy: 0.5900 - val_loss: 4.9133 - val_accuracy: 0.1457
# Epoch 51/100
# 127/127 [==============================] - 18s 143ms/step - loss: 1.4047 - accuracy: 0.5992 - val_loss: 4.3238 - val_accuracy: 0.1844
# Epoch 52/100
# 127/127 [==============================] - 17s 137ms/step - loss: 1.3427 - accuracy: 0.6153 - val_loss: 4.5169 - val_accuracy: 0.1878
# Epoch 53/100
# 127/127 [==============================] - 18s 142ms/step - loss: 1.3413 - accuracy: 0.6193 - val_loss: 4.4210 - val_accuracy: 0.1897
# Epoch 54/100
# 127/127 [==============================] - 18s 142ms/step - loss: 1.3263 - accuracy: 0.6280 - val_loss: 4.3550 - val_accuracy: 0.1995
# Epoch 55/100
# 127/127 [==============================] - 17s 137ms/step - loss: 1.2973 - accuracy: 0.6317 - val_loss: 4.9022 - val_accuracy: 0.1506
# Epoch 56/100
# 127/127 [==============================] - 17s 136ms/step - loss: 1.2896 - accuracy: 0.6386 - val_loss: 5.1000 - val_accuracy: 0.1384
# Epoch 57/100
# 127/127 [==============================] - 18s 144ms/step - loss: 1.2767 - accuracy: 0.6336 - val_loss: 5.3223 - val_accuracy: 0.1193
# Epoch 58/100
# 127/127 [==============================] - 19s 148ms/step - loss: 1.2456 - accuracy: 0.6444 - val_loss: 4.9580 - val_accuracy: 0.1643
# Epoch 59/100
# 127/127 [==============================] - 18s 138ms/step - loss: 1.2165 - accuracy: 0.6534 - val_loss: 4.8028 - val_accuracy: 0.1839
# Epoch 60/100
# 127/127 [==============================] - 17s 130ms/step - loss: 1.2137 - accuracy: 0.6522 - val_loss: 4.7573 - val_accuracy: 0.1731
# Epoch 61/100
# 127/127 [==============================] - 17s 134ms/step - loss: 1.1695 - accuracy: 0.6698 - val_loss: 4.7993 - val_accuracy: 0.1736
# Epoch 62/100
# 127/127 [==============================] - 17s 135ms/step - loss: 1.1448 - accuracy: 0.6681 - val_loss: 4.7302 - val_accuracy: 0.1756
# Epoch 63/100
# 127/127 [==============================] - 16s 128ms/step - loss: 1.1326 - accuracy: 0.6742 - val_loss: 4.8548 - val_accuracy: 0.1619
# Epoch 64/100
# 127/127 [==============================] - 16s 129ms/step - loss: 1.0913 - accuracy: 0.6800 - val_loss: 5.1789 - val_accuracy: 0.1653
# Epoch 65/100
# 127/127 [==============================] - 16s 128ms/step - loss: 1.0880 - accuracy: 0.6898 - val_loss: 5.0134 - val_accuracy: 0.1746
# Epoch 66/100
# 127/127 [==============================] - 16s 129ms/step - loss: 1.0560 - accuracy: 0.6936 - val_loss: 4.6871 - val_accuracy: 0.1834
# Epoch 67/100
# 127/127 [==============================] - 16s 128ms/step - loss: 1.0684 - accuracy: 0.6963 - val_loss: 5.1563 - val_accuracy: 0.1501
# Epoch 68/100
# 127/127 [==============================] - 17s 131ms/step - loss: 1.0452 - accuracy: 0.6968 - val_loss: 4.8452 - val_accuracy: 0.1736
# Epoch 69/100
# 127/127 [==============================] - 18s 139ms/step - loss: 1.0980 - accuracy: 0.6826 - val_loss: 5.2952 - val_accuracy: 0.1633
# Epoch 70/100
# 127/127 [==============================] - 17s 137ms/step - loss: 1.0346 - accuracy: 0.6979 - val_loss: 5.0569 - val_accuracy: 0.1731
# Epoch 71/100
# 127/127 [==============================] - 17s 132ms/step - loss: 0.9983 - accuracy: 0.7091 - val_loss: 5.1076 - val_accuracy: 0.1672
# Epoch 72/100
# 127/127 [==============================] - 17s 136ms/step - loss: 0.9770 - accuracy: 0.7192 - val_loss: 5.0812 - val_accuracy: 0.1731
# Epoch 73/100
# 127/127 [==============================] - 17s 131ms/step - loss: 0.9887 - accuracy: 0.7168 - val_loss: 5.0829 - val_accuracy: 0.1619
# Epoch 74/100
# 127/127 [==============================] - 16s 130ms/step - loss: 1.0119 - accuracy: 0.7108 - val_loss: 5.0063 - val_accuracy: 0.1834
# Epoch 75/100
# 127/127 [==============================] - 16s 128ms/step - loss: 0.9387 - accuracy: 0.7166 - val_loss: 4.9481 - val_accuracy: 0.1951
# Epoch 76/100
# 127/127 [==============================] - 16s 129ms/step - loss: 0.9535 - accuracy: 0.7230 - val_loss: 5.2421 - val_accuracy: 0.1614
# Epoch 77/100
# 127/127 [==============================] - 17s 133ms/step - loss: 0.9176 - accuracy: 0.7281 - val_loss: 5.0055 - val_accuracy: 0.1702
# Epoch 78/100
# 127/127 [==============================] - 17s 131ms/step - loss: 0.9454 - accuracy: 0.7237 - val_loss: 5.3493 - val_accuracy: 0.1579
# Epoch 79/100
# 127/127 [==============================] - 17s 130ms/step - loss: 0.9414 - accuracy: 0.7297 - val_loss: 5.3994 - val_accuracy: 0.1575
# Epoch 80/100
# 127/127 [==============================] - 17s 130ms/step - loss: 0.8927 - accuracy: 0.7398 - val_loss: 5.3266 - val_accuracy: 0.1589
# Epoch 81/100
# 127/127 [==============================] - 17s 130ms/step - loss: 0.8986 - accuracy: 0.7370 - val_loss: 4.8846 - val_accuracy: 0.1888
# Epoch 82/100
# 127/127 [==============================] - 17s 131ms/step - loss: 0.8709 - accuracy: 0.7425 - val_loss: 5.2055 - val_accuracy: 0.1824
# Epoch 83/100
# 127/127 [==============================] - 17s 131ms/step - loss: 0.8481 - accuracy: 0.7468 - val_loss: 5.4727 - val_accuracy: 0.1667
# Epoch 84/100
# 127/127 [==============================] - 17s 131ms/step - loss: 0.8333 - accuracy: 0.7552 - val_loss: 5.5310 - val_accuracy: 0.1550
# Epoch 85/100
# 127/127 [==============================] - 17s 130ms/step - loss: 0.8074 - accuracy: 0.7566 - val_loss: 5.8160 - val_accuracy: 0.1472
# Epoch 86/100
# 127/127 [==============================] - 17s 130ms/step - loss: 0.8362 - accuracy: 0.7543 - val_loss: 5.2647 - val_accuracy: 0.1829
# Epoch 87/100
# 127/127 [==============================] - 17s 130ms/step - loss: 0.8212 - accuracy: 0.7616 - val_loss: 5.0967 - val_accuracy: 0.1790
# Epoch 88/100
# 127/127 [==============================] - 16s 130ms/step - loss: 0.8090 - accuracy: 0.7662 - val_loss: 5.5487 - val_accuracy: 0.1604
# Epoch 89/100
# 127/127 [==============================] - 17s 130ms/step - loss: 0.8258 - accuracy: 0.7558 - val_loss: 5.4961 - val_accuracy: 0.1648
# Epoch 90/100
# 127/127 [==============================] - 17s 130ms/step - loss: 0.7656 - accuracy: 0.7693 - val_loss: 5.3753 - val_accuracy: 0.1804
# Epoch 91/100
# 127/127 [==============================] - 17s 131ms/step - loss: 0.8023 - accuracy: 0.7649 - val_loss: 5.5425 - val_accuracy: 0.1785
# Epoch 92/100
# 127/127 [==============================] - 18s 140ms/step - loss: 0.7691 - accuracy: 0.7699 - val_loss: 5.6231 - val_accuracy: 0.1579
# Epoch 93/100
# 127/127 [==============================] - 17s 132ms/step - loss: 0.7548 - accuracy: 0.7768 - val_loss: 5.0245 - val_accuracy: 0.1917
# Epoch 94/100
# 127/127 [==============================] - 17s 131ms/step - loss: 0.7683 - accuracy: 0.7677 - val_loss: 5.3518 - val_accuracy: 0.1741
# Epoch 95/100
# 127/127 [==============================] - 17s 136ms/step - loss: 0.7530 - accuracy: 0.7747 - val_loss: 5.0889 - val_accuracy: 0.1892
# Epoch 96/100
# 127/127 [==============================] - 17s 133ms/step - loss: 0.7622 - accuracy: 0.7753 - val_loss: 5.2174 - val_accuracy: 0.1756
# Epoch 97/100
# 127/127 [==============================] - 17s 137ms/step - loss: 0.7678 - accuracy: 0.7773 - val_loss: 5.2226 - val_accuracy: 0.1917
# Epoch 98/100
# 127/127 [==============================] - 18s 138ms/step - loss: 0.7250 - accuracy: 0.7823 - val_loss: 5.5858 - val_accuracy: 0.1775
# Epoch 99/100
# 127/127 [==============================] - 17s 131ms/step - loss: 0.7091 - accuracy: 0.7912 - val_loss: 5.0086 - val_accuracy: 0.1912
# Epoch 100/100
# 127/127 [==============================] - 17s 132ms/step - loss: 0.6867 - accuracy: 0.7964 - val_loss: 5.0725 - val_accuracy: 0.2029
# INFO:tensorflow:Assets written to: my_model2\assets
